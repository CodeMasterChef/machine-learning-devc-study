# %% [markdown]
# ![](https://i.imgur.com/0AUxkXt.png)

# %% [markdown]
# # Lecture 1 - Basic Python & SQL

# %% [markdown]
# ## Basic Python

# %% [markdown]
# ### Variables and data types
#
# **DAwP is awesome**
#
# *That's right*
#
# * 1
# * 2
#
# ```
# print('Hello World')
# ```

# %%
# integer
# Out:
# 101
# int

# %%
# float - number with decimal point
# Out:
# 5
# float

# %%
x = 15
y = 4
print(x + y)
print(x - y)
print(x / y)
print(x * y)
print('---')
print(x // 2)
print(x % 2)

print(21 // 5)
print(27 % 3)

x = 5
x % 2 == 1
# Out:
# 103.5
# 98.5
# 40.4
# 252.5
# ---
# 50
# 1
# 4
# 0
# True

# %%
# string
# Out:
# 'hello' "world"

# %%
message = s1 + ' ' + s2
print(message)
# Out:
# 'hello' "world"

# %%
# logical
b = True
print(not b)
print(type(b))
# Out:
# False
# <class 'bool'>

# %%
print('2 < 3 :', 2 < 3)
print('10 > 20 :', 10 > 20)
print('4 == 5 :', 4 == 5)
print('4 != 5 :', 4 != 5)

x = 3
min = 1
max = 5
print(x, 'is not between', min, 'and', max, ':', not ((x >= min) and (x <= max))) 
# How about not between?
# Out:
# 2 < 3 : True
# 10 > 20 : False
# 4 == 5 : False
# 4 != 5 : True
# 3 is not between 1 and 5 : False

# %% [markdown]
# ### The if-statement

# %%
import numpy as np

x = np.random.randint(10)
x
# Out:
# 8

# %%
x = np.random.randint(10)
# x = 3
answer = ''
if x > 5: 
    answer = "Greater than 5"
elif x < 3:
    answer = "Less than 3"
else:
    if x == 3:
        answer = "equal 3"
    elif x == 4:
        answer = "equal 4"
    else:
        answer = "equal 5"
print(x)
print(answer)

# Notice the code indentation
# Out:
# 3
# equal 3

# %% [markdown]
# ### The for-loop

# %%
a = [3, 4, 5, 3, 4]
# Out:
# [4, 5, 3]
# Hello Python
# 3
# Hello Python
# 4
# Hello Python
# 5
# Hello Python
# 3
# Hello Python
# 4

# %%
list(range(3))
# Out:
# [0, 1, 2]

# %%
list(range(3, 5))
# Out:
# [3, 4]

# %%
# Another way
myList = [1, 2, 5, 10, 20, 50, 100, 200, 500]

# Your code here
# Out:
# --- values in the list ---
# 1
# 2
# 5
# 10
# 20
# 50
# 100
# 200
# 500
# --- enumerate ---
# 0 1
# 1 2
# 2 5
# 3 10
# 4 20
# 5 50
# 6 100
# 7 200
# 8 500
# 200

# %% [markdown]
# ### The while-loop

# %%
counter = 0
while (counter < 12):
    print(counter)d
    counter = counter + 2
# Out:
# 0
# 2
# 4
# 6
# 8
# 10

# %% [markdown]
# ### Example: Money exchange

# %%
money = 2300
origin = money

values = [500, 200, 100, 50, 20, 10, 5, 2, 1]
result = [0, 0, 0, 0, 0, 0, 0, 0, 0]
# Out:
# [4, 1, 1, 0, 0, 0, 0, 0, 0]
# 0
# 2300 can be exchanged with
# 4 x 500 k
# 1 x 200 k
# 1 x 100 k

# %% [markdown]
# ### The function

# %%
def exchange(money):
  # Your code here
  pass

# %%
exchange(2400)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-9e58b5ca8fb0> in <module>()
# ----> 1 exchange(2400)
#
# NameError: name 'exchange' is not defined

# %%
print(myList)
myList[:5][:5]
# Out:
# [1, 2, 5, 10, 20, 50, 100, 200, 500]
# [1, 2, 5, 10, 20, 50, 100, 200, 500]

# %% [markdown]
# ### Practice

# %% [markdown]
# #### Problem 1
#
# This problem was recently asked by Google.
#
# Given a list of numbers and a number k, return whether any two numbers from the list add up to k.
#
# For example, given [10, 15, 3, 7] and k of 17, return true since 10 + 7 is 17.
#
# Bonus: Can you do this in one pass?

# %% [markdown]
# #### Problem 2

# %% [markdown]
# This problem was asked by Stripe.
#
# Given an array of integers, find the first missing positive integer in linear time and constant space. In other words, find the lowest positive integer that does not exist in the array. The array can contain duplicates and negative numbers as well.
#
# For example, the input [3, 4, -1, 1] should give 2. The input [1, 2, 0] should give 3.
#
# You can modify the input array in-place.

# %% [markdown]
# #### Problem 3
# Write a function that rotates a list by k elements. For example, [1, 2, 3, 4, 5, 6] rotated by two becomes [3, 4, 5, 6, 1, 2]. Try solving this without creating a copy of the list. How many swap or move operations do you need?

# %% [markdown]
# ## SQL - Structured Query Language

# %% [markdown]
# ![](https://i.imgur.com/kCaiMK5.png)

# %%
# Download database
# !wget https://ml101-khanhnguyen.s3-ap-southeast-1.amazonaws.com/devc/chinook.db
# Out:
# --2019-07-15 08:45:40--  https://ml101-khanhnguyen.s3-ap-southeast-1.amazonaws.com/devc/chinook.db
# Resolving ml101-khanhnguyen.s3-ap-southeast-1.amazonaws.com (ml101-khanhnguyen.s3-ap-southeast-1.amazonaws.com)... 52.219.32.159
# Connecting to ml101-khanhnguyen.s3-ap-southeast-1.amazonaws.com (ml101-khanhnguyen.s3-ap-southeast-1.amazonaws.com)|52.219.32.159|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 884736 (864K) [binary/octet-stream]
# Saving to: ‘chinook.db’
#
# chinook.db          100%[===================>] 864.00K   778KB/s    in 1.1s
#
# 2019-07-15 08:45:47 (778 KB/s) - ‘chinook.db’ saved [884736/884736]

# %%
import sqlite3
conn = sqlite3.connect('chinook.db')

# %%
cur = conn.cursor()

# %%
cur.execute('SELECT * FROM albums LIMIT 5;')

# %%
results = cur.fetchall()
print(results)
# Out:
# [(1, 'For Those About To Rock We Salute You', 1), (2, 'Balls to the Wall', 2), (3, 'Restless and Wild', 2), (4, 'Let There Be Rock', 1), (5, 'Big Ones', 3)]

# %%
import pandas as pd
df = pd.read_sql_query('SELECT albumid, title FROM albums LIMIT 10;', conn)
df
# Out:
#    AlbumId                                  Title
# 0        1  For Those About To Rock We Salute You
# 1        2                      Balls to the Wall
# 2        3                      Restless and Wild
# 3        4                      Let There Be Rock
# 4        5                               Big Ones
# 5        6                     Jagged Little Pill
# 6        7                               Facelift
# 7        8                         Warner 25 Anos
# 8        9         Plays Metallica By Four Cellos
# 9       10                             Audioslave

# %%
df = pd.read_sql_query('SELECT * FROM albums ORDER BY title LIMIT 5;', conn)
df
# Out:
#    AlbumId                                              Title  ArtistId
# 0      156                             ...And Justice For All        50
# 1      257  20th Century Masters - The Millennium Collecti...       179
# 2      296                      A Copland Celebration, Vol. I       230
# 3       94                         A Matter of Life and Death        90
# 4       95                                    A Real Dead One        90
